# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')
df
# Out:
#          ID  Building  Year of sale  Month of sale Type of property  \
# 0    1030.0       1.0        2005.0           11.0        Apartment
# 1    1029.0       1.0        2005.0           10.0        Apartment
# 2    2002.0       2.0        2007.0            7.0        Apartment
# 3    2031.0       2.0        2007.0           12.0        Apartment
# 4    1049.0       1.0        2004.0           11.0        Apartment
# ..      ...       ...           ...            ...              ...
# 263  5047.0       5.0           NaN            NaN        Apartment
# 264  5048.0       5.0           NaN            NaN        Apartment
# 265  5050.0       5.0           NaN            NaN        Apartment
# 266  5051.0       5.0           NaN            NaN        Apartment
# 267     NaN       NaN           NaN            NaN              NaN
#
#      Property #  Area (ft.)      Price  Status  Unnamed: 9  ...       Y     M  \
# ...

# %%
del df['Unnamed: 9']

# %%
df
# Out:
#          ID  Building  Year of sale  Month of sale Type of property  \
# 0    1030.0       1.0        2005.0           11.0        Apartment
# 1    1029.0       1.0        2005.0           10.0        Apartment
# 2    2002.0       2.0        2007.0            7.0        Apartment
# 3    2031.0       2.0        2007.0           12.0        Apartment
# 4    1049.0       1.0        2004.0           11.0        Apartment
# ..      ...       ...           ...            ...              ...
# 263  5047.0       5.0           NaN            NaN        Apartment
# 264  5048.0       5.0           NaN            NaN        Apartment
# 265  5050.0       5.0           NaN            NaN        Apartment
# 266  5051.0       5.0           NaN            NaN        Apartment
# 267     NaN       NaN           NaN            NaN              NaN
#
#      Property #  Area (ft.)      Price  Status Customer ID  ...       Y     M  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 267 non-null    float64
#  1   Building           267 non-null    float64
#  2   Year of sale       195 non-null    float64
#  3   Month of sale      195 non-null    float64
#  4   Type of property   267 non-null    object
#  5   Property #         267 non-null    float64
#  6   Area (ft.)         267 non-null    float64
#  7   Price              267 non-null    float64
#  8   Status             195 non-null    object
#  9   Customer ID        195 non-null    object
#  10  Entity             195 non-null    object
#  11  Name               195 non-null    object
#  12  Surname            195 non-null    object
#  13  Age                179 non-null    object
#  14  Interval           178 non-null    object
#  15  Y                  178 non-null    float64
# ...

# %%
df.describe()
# Out:
#                 ID    Building  Year of sale  Month of sale  Property #  \
# count   267.000000  267.000000    195.000000     195.000000  267.000000
# mean   2975.142322    2.947566   2006.333333       7.271795   27.580524
# std    1392.197474    1.391794      1.072941       3.378674   15.361437
# min    1002.000000    1.000000   2004.000000       1.000000    1.000000
# 25%    2015.500000    2.000000   2006.000000       4.000000   14.500000
# 50%    3024.000000    3.000000   2007.000000       8.000000   28.000000
# 75%    4031.500000    4.000000   2007.000000      10.000000   40.000000
# max    5052.000000    5.000000   2010.000000      12.000000   59.000000
#
#         Area (ft.)          Price            Y           M           D  \
# count   267.000000     267.000000   178.000000  178.000000  178.000000
# mean    936.221311  281171.901386  1960.325843    6.752809   15.449438
# std     284.894858   89119.121005    12.835575    3.450312    8.457285
# ...

# %%
df['Gender'].fillna('firm',inplace=True)

# %%
df['Gender']
# Out:
# 0         F
# 1         F
# 2         M
# 3         M
# 4         F
#        ...
# 263    firm
# 264    firm
# 265    firm
# 266    firm
# 267    firm
# Name: Gender, Length: 268, dtype: object

# %%
df['Gender'].value_counts()
# Out:
# M       108
# firm     90
# F        70
# Name: Gender, dtype: int64

# %%
labels = 'Male', 'Female', 'Firm'
sizes = [108, 70, 90]
fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct='%.f%%')
ax1.axis('equal') 
plt.title("Gender Value Count")
# Out:
# Text(0.5, 1.0, 'Gender Value Count')

# %%
df = pd.DataFrame({
    'Gender': ['Male', 'Female', 'Firm'],
    'cont': [108,70,90]
})

# %%
df.plot(kind='bar', x='Gender', y='cont', legend=None, title='Gender Value Count')
plt.show()

# %%
df.plot(kind='pie', labels=df['Gender'], y='cont', legend=None, autopct='%.2f%%', title='Gender Value Count')
plt.tight_layout()
plt.show()

# %%
def pareto_plot(df, x=None, y=None, title=None, show_pct_y=False, pct_format='{0:.0%}'):
    xlabel = x
    ylabel = y
    tmp = df.sort_values(y, ascending=False)
    x = tmp[x].values
    y = tmp[y].values
    weights = y / y.sum()
    cumsum = weights.cumsum()
    
    fig, ax1 = plt.subplots()
    ax1.bar(x, y)
    ax1.set_xlabel(xlabel)
    ax1.set_ylabel(ylabel)

    ax2 = ax1.twinx()
    ax2.plot(x, cumsum, '-ro', alpha=0.5)
    ax2.set_ylabel('', color='r')
    ax2.tick_params('y', colors='r')
    
    vals = ax2.get_yticks()
    ax2.set_yticklabels(['{:,.2%}'.format(x) for x in vals])

    # hide y-labels on right side
    if not show_pct_y:
        ax2.set_yticks([])
    
    formatted_weights = [pct_format.format(x) for x in cumsum]
    for i, txt in enumerate(formatted_weights):
        ax2.annotate(txt, (x[i], cumsum[i]), fontweight='heavy')    
    
    if title:
        plt.title(title)
    
    plt.tight_layout()
    plt.show()

# %%
pareto_plot(df, x='Gender', y='cont', title='Gender Value Count')

# %%
df = pd.DataFrame({
    'States': ['California ','Nevada ','Oregon ','Arizona ','Colorado ','Utah ','Virginia ','Wyoming ','Kansas ','(Noneabroad) '
],
    'Value': [119,17,11,11,11,6,4,1,18,6]
})

# %%
df.plot(kind='bar', x='States', y='Value', legend=None, title='Segmentation of US clients by State')
plt.show()

# %%
def pareto_plot(df, x=None, y=None, title=None, show_pct_y=False, pct_format='{0:.0%}'):
    xlabel = x
    ylabel = y
    tmp = df.sort_values(y, ascending=False)
    x = tmp[x].values
    y = tmp[y].values
    weights = y / y.sum()
    cumsum = weights.cumsum()
    
    fig, ax1 = plt.subplots()
    ax1.bar(x, y)
    ax1.set_xlabel(xlabel)
    ax1.set_ylabel(ylabel)

    ax2 = ax1.twinx()
    ax2.plot(x, cumsum, '-ro', alpha=0.8)
    ax2.set_ylabel('', color='r')
    ax2.tick_params('y', colors='r')
    
    vals = ax2.get_yticks()
    ax2.set_yticklabels(['{:,.2%}'.format(x) for x in vals])

    # hide y-labels on right side
    if not show_pct_y:
        ax2.set_yticks([])
    
    formatted_weights = [pct_format.format(x) for x in cumsum]
    for i, txt in enumerate(formatted_weights):
        ax2.annotate(txt, (x[i], cumsum[i]), fontweight='normal')    
    
    if title:
        plt.title(title)
    
    plt.tight_layout()
    plt.show()

# %%
pareto_plot(df, x='States', y='Value', title='Segmentation of US clients by State')
